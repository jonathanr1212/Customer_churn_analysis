# %% [markdown]
# # Overview
#
# This project uses Machine Learning (ML) to make predictions on a binary classification target for a telecommunications company. The information came from a dataset provided on kaggle from SyriaTel. Models are used to make the best predictions to find out why customers have churned.(left the company)

# %% [markdown]
# # Business Problem
#
# SyriaTel wants to reduce the amount of money lost by checking what are the factors that have made consumers churn. This analysis can help predict which customers have the possibility of churning and find a way to retain them for the future.

# %% [markdown]
# # Data Preparation and EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score, f1_score, 
    mean_squared_error, confusion_matrix, plot_confusion_matrix, roc_auc_score, classification_report
)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from xgboost import XGBClassifier

# %%
df = pd.read_csv('data/bigml_59c28831336c6604c800002a.csv')
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
df.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df['churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: churn, dtype: int64

# %%
#Formatting target boolean values to integer values to be able to put through machine learning modeling
df_2 = df.copy()

# %%
df_2['churn'] = df_2['churn'].astype('int64')

# %%
#Checking Value counts to see if the dataset has a class imbalance. 
df_2.churn.value_counts()
# Out:
# 0    2850
# 1     483
# Name: churn, dtype: int64

# %%
#Converting binary information into integers
df_2['international plan'], df_2['voice mail plan'] = (df_2['international plan'].map(dict(no= 0, yes= 1)), 
                                                      df_2['voice mail plan'].map(dict(no= 0, yes= 1)))

# %%
#double checking to see if everything was encoded properly
print(df['international plan'].value_counts())
print(df['voice mail plan'].value_counts())
print(df_2['international plan'].value_counts())
print(df_2['voice mail plan'].value_counts())
# Out:
# no     3010
# yes     323
# Name: international plan, dtype: int64
# no     2411
# yes     922
# Name: voice mail plan, dtype: int64
# 0    3010
# 1     323
# Name: international plan, dtype: int64
# 0    2411
# 1     922
# Name: voice mail plan, dtype: int64

# %%
#dropping phone numbers and area codes
df_2.drop(['phone number', 'area code'], axis=1, inplace=True)
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   international plan      3333 non-null   int64
#  3   voice mail plan         3333 non-null   int64
#  4   number vmail messages   3333 non-null   int64
#  5   total day minutes       3333 non-null   float64
#  6   total day calls         3333 non-null   int64
#  7   total day charge        3333 non-null   float64
#  8   total eve minutes       3333 non-null   float64
#  9   total eve calls         3333 non-null   int64
#  10  total eve charge        3333 non-null   float64
#  11  total night minutes     3333 non-null   float64
#  12  total night calls       3333 non-null   int64
#  13  total night charge      3333 non-null   float64
# ...

# %%
df_2.hist();

# %%
#Cgecking counts for the categorical data
sns.countplot(y='state', data=df_2, color='tab:blue')
sns.set(rc={'figure.figsize':(30,40)}, font_scale= 3);

# %%
#Checking churn by state
states = df_2.groupby('state')['churn'].value_counts(normalize=True)
states = pd.DataFrame(states)
states.columns = ['percent']
states = states.reset_index()
states
# Out:
#     state  churn   percent
# 0      AK      0  0.942308
# 1      AK      1  0.057692
# 2      AL      0  0.900000
# 3      AL      1  0.100000
# 4      AR      0  0.800000
# ..    ...    ...       ...
# 97     WI      1  0.089744
# 98     WV      0  0.905660
# 99     WV      1  0.094340
# 100    WY      0  0.883117
# 101    WY      1  0.116883
#
# [102 rows x 3 columns]

# %%
#Checking churn rate by state
states_churn_rate = states.loc[states['churn'] == 1].sort_values("percent", ascending =False).reset_index().drop(
    "index", axis =1)
states_churn_rate
# Out:
#    state  churn   percent
# 0     NJ      1  0.264706
# 1     CA      1  0.264706
# 2     TX      1  0.250000
# 3     MD      1  0.242857
# 4     SC      1  0.233333
# 5     MI      1  0.219178
# 6     MS      1  0.215385
# 7     NV      1  0.212121
# 8     WA      1  0.212121
# 9     ME      1  0.209677
# 10    MT      1  0.205882
# 11    AR      1  0.200000
# 12    KS      1  0.185714
# 13    NY      1  0.180723
# 14    MN      1  0.178571
# 15    PA      1  0.177778
# 16    MA      1  0.169231
# 17    CT      1  0.162162
# 18    NC      1  0.161765
# 19    NH      1  0.160714
# 20    GA      1  0.148148
# 21    DE      1  0.147541
# 22    OK      1  0.147541
# 23    OR      1  0.141026
# 24    UT      1  0.138889
# 25    CO      1  0.136364
# 26    KY      1  0.135593
# 27    SD      1  0.133333
# 28    OH      1  0.128205
# 29    FL      1  0.126984
# 30    IN      1  0.126761
# 31    ID      1  0.123288
# 32    WY      1  0.116883
# 33    MO      1  0.111111
# ...

# %%
#categorizing states churn rate into high at 20% and above, mid to 10%-19%, and low to 9% and lower.
high_churn, mid_churn, low_churn = (states_churn_rate.loc[states_churn_rate['percent'] >= .2], 
                                    
                                    states_churn_rate.loc[(states_churn_rate['percent'] < .2) & (
                                        states_churn_rate['percent'] >= .1)], 
                                    
                                    states_churn_rate.loc[states_churn_rate['percent'] < .1])

high_churn_states, mid_churn_states, low_churn_states  = (high_churn['state'],
                                                          mid_churn['state'],
                                                          low_churn['state'])

print("States with a high churn rate: ", list(high_churn_states))
print('\n----------------------------------------------------------------\n')
print("States with a medium churn rate: ", list(mid_churn_states))
print('\n-----------------------------------------------------------------\n')
print("States with a low churn rate: ", list(low_churn_states))
# Out:
# States with a high churn rate:  ['NJ', 'CA', 'TX', 'MD', 'SC', 'MI', 'MS', 'NV', 'WA', 'ME', 'MT', 'AR']
#
# ----------------------------------------------------------------
#
# States with a medium churn rate:  ['KS', 'NY', 'MN', 'PA', 'MA', 'CT', 'NC', 'NH', 'GA', 'DE', 'OK', 'OR', 'UT', 'CO', 'KY', 'SD', 'OH', 'FL', 'IN', 'ID', 'WY', 'MO', 'VT', 'AL']
#
# -----------------------------------------------------------------
#
# States with a low churn rate:  ['NM', 'ND', 'WV', 'TN', 'DC', 'RI', 'WI', 'IL', 'NE', 'LA', 'IA', 'VA', 'AZ', 'AK', 'HI']

# %%
num_list = df_2.select_dtypes(include=['int64', 'float64', 'int32'])
for col in num_list:
    fig, axes = plt.subplots(1, 1, figsize=(4,4))
    sns.boxplot(y = df_2['churn'].astype('category'), x =col , data=df_2, orient='h')
    sns.set(font_scale= 1.5)

# %%
#checking for possible outlier removal
df_2_value_counts = df_2[['customer service calls', 'total intl calls', 'total eve charge', 'total day calls']]
for counts in (df_2_value_counts):
    print(df_2_value_counts[counts].value_counts(), "-------------------------")
# Out:
# 1    1181
# 2     759
# 0     697
# 3     429
# 4     166
# 5      66
# 6      22
# 7       9
# 9       2
# 8       2
# Name: customer service calls, dtype: int64 -------------------------
# 3     668
# 4     619
# 2     489
# 5     472
# 6     336
# 7     218
# 1     160
# 8     116
# 9     109
# 10     50
# 11     28
# 0      18
# 12     15
# 13     14
# 15      7
# 14      6
# 18      3
# 16      2
# 19      1
# 17      1
# 20      1
# Name: total intl calls, dtype: int64 -------------------------
# 14.25    11
# 16.12    11
# 15.90    10
# 18.62     9
# 14.44     9
#          ..
# 12.64     1
# 13.83     1
# 11.39     1
# 28.03     1
# 20.53     1
# Name: total eve charge, Length: 1440, dtype: int64 -------------------------
# 102    78
# 105    75
# 107    69
# 95     69
# 104    68
#        ..
# 149     1
# 157     1
# 36      1
# 30      1
# 165     1
# Name: total day calls, Length: 119, dtype: int64 -------------------------

# %% [markdown]
# ### Model Preparation

# %%
#setting x and y for model preparation
X = df_2.drop('churn', axis=1)
y = df_2['churn']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 1)

# %%
X_train_num = X_train.select_dtypes(include=['float64', 'int64', 'int32'])
X_train_cat = X_train.select_dtypes('object')

# %%
num_pipeline = Pipeline(steps=[
    ('ss', StandardScaler())
])
                
cat_pipeline = Pipeline(steps=[
    ('ohe', OneHotEncoder(handle_unknown='ignore',
                         sparse=False))
])

transformer = ColumnTransformer(transformers=[
    ('numerical', num_pipeline, X_train_num.columns),
    ('categorical', cat_pipeline, X_train_cat.columns)])

# %% [markdown]
# # Modeling

# %% [markdown]
# ## <u>Dummy Model

# %%
#Starting off with a dummy model to check how accurate the model would be if we just chose the most frequent.
dummy_pipe = Pipeline(steps=[
    ('transformer', transformer),
    ('dummy', DummyClassifier(strategy="most_frequent"))]) 

dummy_pipe.fit(X_train, y_train)
dummy_pipe.predict(X_train)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
cv_results = cross_val_score(dummy_pipe, X_train, y_train, cv=5)
cv_results.mean()
# Out:
# 0.8555422845691384

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(dummy_pipe, X_train, y_train, normalize='true', ax=ax)
plt.grid(False);

# %% [markdown]
# ## <u>Logistic Regression

# %% [markdown]
# ### Logistic Regression Model 1

# %%
baseline_logreg_pipe = Pipeline(steps=[
    ('transformer', transformer),
    ('logreg', LogisticRegression(random_state=1))])

# %%
baseline_logreg_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('ss',
#                                                                    StandardScaler())]),
#                                                   Index(['account length', 'international plan', 'voice mail plan',
#        'number vmail messages', 'total day minutes', 'total day calls',
#        'total day charge', 'total eve minutes', 'total eve calls',
#        'total eve charge', 'total night minutes', 'total night calls',
#        'total night charge', 'total intl minutes', 'total intl calls',
#        'total intl charge', 'customer service calls'],
#       dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('ohe',
# ...

# %%
y_pred = baseline_logreg_pipe.predict(X_train)

# %% [markdown]
# ### Logistic Regression Model 1 Evaluation

# %% [markdown]
# #### Train set check

# %%
scores = cross_val_score(baseline_logreg_pipe, X_train, y_train, cv=5 )
scores.mean()
# Out:
# 0.8671486973947896

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93      2138
#            1       0.61      0.27      0.38       361
#
#     accuracy                           0.87      2499
#    macro avg       0.75      0.62      0.65      2499
# weighted avg       0.85      0.87      0.85      2499

# %%
cm_1 = confusion_matrix(y_train, y_pred)
cm_1
# Out:
# array([[2076,   62],
#        [ 263,   98]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(baseline_logreg_pipe, X_train, y_train, normalize='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# #### Test set check

# %%
print(classification_report(y_test, baseline_logreg_pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92       712
#            1       0.48      0.22      0.30       122
#
#     accuracy                           0.85       834
#    macro avg       0.68      0.59      0.61       834
# weighted avg       0.82      0.85      0.83       834

# %%
cm_2 = confusion_matrix(y_test, baseline_logreg_pipe.predict(X_test))
cm_2
# Out:
# array([[683,  29],
#        [ 95,  27]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(baseline_logreg_pipe, X_test, y_test, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# #### Feature importance

# %%
importance = baseline_logreg_pipe['logreg'].coef_[0]

# %%
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: 0, Score: 0.05084
# Feature: 1, Score: 0.64867
# Feature: 2, Score: -0.69582
# Feature: 3, Score: 0.24715
# Feature: 4, Score: 0.35242
# Feature: 5, Score: 0.05877
# Feature: 6, Score: 0.35655
# Feature: 7, Score: 0.19016
# Feature: 8, Score: 0.03061
# Feature: 9, Score: 0.19035
# Feature: 10, Score: 0.12501
# Feature: 11, Score: -0.00549
# Feature: 12, Score: 0.11714
# Feature: 13, Score: 0.10056
# Feature: 14, Score: -0.33562
# Feature: 15, Score: 0.12086
# Feature: 16, Score: 0.75299
# Feature: 17, Score: -0.76529
# Feature: 18, Score: -0.28709
# Feature: 19, Score: 0.37965
# Feature: 20, Score: -0.11215
# Feature: 21, Score: 0.60141
# Feature: 22, Score: 0.05290
# Feature: 23, Score: 0.21057
# Feature: 24, Score: -0.06845
# Feature: 25, Score: 0.09132
# Feature: 26, Score: 0.06897
# Feature: 27, Score: 0.02387
# Feature: 28, Score: -0.59999
# Feature: 29, Score: -0.46524
# Feature: 30, Score: 0.04187
# Feature: 31, Score: -1.18280
# Feature: 32, Score: -0.16233
# ...

# %% [markdown]
# ### Logistic Regression Model 2 (with class weights)

# %%
y_train.value_counts()
# Out:
# 0    2138
# 1     361
# Name: churn, dtype: int64

# %%
baseline_logreg_pipe_with_cw = Pipeline(steps=[
    ('transformer', transformer),
    ('logreg', LogisticRegression(random_state=2, class_weight='balanced'))])

# %%
baseline_logreg_pipe_with_cw.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('ss',
#                                                                    StandardScaler())]),
#                                                   Index(['account length', 'international plan', 'voice mail plan',
#        'number vmail messages', 'total day minutes', 'total day calls',
#        'total day charge', 'total eve minutes', 'total eve calls',
#        'total eve charge', 'total night minutes', 'total night calls',
#        'total night charge', 'total intl minutes', 'total intl calls',
#        'total intl charge', 'customer service calls'],
#       dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('ohe',
# ...

# %%
y_pred_cw = baseline_logreg_pipe_with_cw.predict(X_train)

# %% [markdown]
# ### Logistic Regression Model 2 (with class weights) Evaluation

# %% [markdown]
# #### Train set check

# %%
scores = cross_val_score(baseline_logreg_pipe_with_cw, X_train, y_train, cv=5 )
scores.mean()
# Out:
# 0.7651166332665331

# %%
print(classification_report(y_train, y_pred_cw))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.78      0.86      2138
#            1       0.37      0.78      0.50       361
#
#     accuracy                           0.78      2499
#    macro avg       0.66      0.78      0.68      2499
# weighted avg       0.87      0.78      0.81      2499

# %%
cm_3 = confusion_matrix(y_train, baseline_logreg_pipe_with_cw.predict(X_train))
cm_3
# Out:
# array([[1661,  477],
#        [  78,  283]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(baseline_logreg_pipe_with_cw, X_train, y_train, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# #### Test set check

# %%
print(classification_report(y_test, baseline_logreg_pipe_with_cw.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85       712
#            1       0.35      0.70      0.47       122
#
#     accuracy                           0.77       834
#    macro avg       0.65      0.74      0.66       834
# weighted avg       0.85      0.77      0.80       834

# %%
cm_4 = confusion_matrix(y_test, baseline_logreg_pipe_with_cw.predict(X_test))
cm_4
# Out:
# array([[555, 157],
#        [ 36,  86]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(baseline_logreg_pipe_with_cw, X_test, y_test, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# ### Logistic Regression Model 3 (with Gridsearch and no class weights)

# %%
logreg_pipe_gs = Pipeline(steps=[
    ('transformer', transformer),
    ('logreg', LogisticRegression(random_state=3))])

# %%
logreg_grid = {'logreg__penalty': ['l1', 'l2', 'elasticnet', 'none'],
              'logreg__C': [1, .01, .001],
              'logreg__solver':['liblinear', 'saga']
              }

# %%
logreg_gs_no_cw =GridSearchCV(estimator=logreg_pipe_gs, param_grid = logreg_grid, cv = 5)

# %%
logreg_gs_no_cw.fit(X_train, y_train)
# Out:
# C:\Users\Jonathan\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\Jonathan\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\Jonathan\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\Jonathan\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# ...

# %% [markdown]
# ### Logistic Regression Model 3 (with Gridsearch and no class weights) Evaluation

# %% [markdown]
# #### Train set check

# %%
logreg_gs_no_cw.best_params_
# Out:
# {'logreg__C': 1, 'logreg__penalty': 'l1', 'logreg__solver': 'liblinear'}

# %%
logreg_gs_no_cw.best_score_
# Out:
# 0.8675503006012024

# %%
logreg_gs_no_cw.best_estimator_.score(X_train, y_train)
# Out:
# 0.8707482993197279

# %%
print(classification_report(y_train, logreg_gs_no_cw.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93      2138
#            1       0.62      0.27      0.38       361
#
#     accuracy                           0.87      2499
#    macro avg       0.75      0.62      0.65      2499
# weighted avg       0.85      0.87      0.85      2499

# %%
cm_5 = confusion_matrix(y_train, logreg_gs_no_cw.predict(X_train))
cm_5
# Out:
# array([[2079,   59],
#        [ 264,   97]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(logreg_gs_no_cw, X_train, y_train, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# #### Test set check

# %%
print(classification_report(y_test, logreg_gs_no_cw.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92       712
#            1       0.47      0.21      0.29       122
#
#     accuracy                           0.85       834
#    macro avg       0.67      0.59      0.60       834
# weighted avg       0.82      0.85      0.83       834

# %%
cm_6 = confusion_matrix(y_test, logreg_gs_no_cw.predict(X_test))
cm_6
# Out:
# array([[683,  29],
#        [ 96,  26]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(logreg_gs_no_cw, X_test, y_test, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# ### Logistic Regression Model 4 (with Gridsearch and class weights)

# %%
logreg_pipe_gs_2 = Pipeline(steps=[
    ('transformer', transformer),
    ('logreg', LogisticRegression(random_state=4, class_weight = 'balanced'))])

# %%
logreg_gs_with_cw = GridSearchCV(estimator=logreg_pipe_gs_2, param_grid = logreg_grid, scoring = 'recall', cv = 5 )

# %%
logreg_gs_with_cw.fit(X_train, y_train)
# Out:
# C:\Users\Jonathan\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\Jonathan\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\Jonathan\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\Jonathan\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# ...

# %% [markdown]
# ### Logistic Regression Model 4 (with Gridsearch and class weights) Evaluation

# %% [markdown]
# #### Train set check

# %%
logreg_gs_with_cw.best_params_
# Out:
# {'logreg__C': 0.01, 'logreg__penalty': 'l1', 'logreg__solver': 'liblinear'}

# %%
logreg_gs_with_cw.best_score_
# Out:
# 0.8394977168949772

# %%
logreg_gs_with_cw.best_estimator_.score(X_train, y_train)
# Out:
# 0.7274909963985594

# %%
print(classification_report(y_train, logreg_gs_with_cw.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.71      0.82      2138
#            1       0.32      0.82      0.47       361
#
#     accuracy                           0.73      2499
#    macro avg       0.64      0.77      0.64      2499
# weighted avg       0.87      0.73      0.77      2499

# %%
cm_7 = confusion_matrix(y_train, logreg_gs_with_cw.predict(X_train))
cm_7
# Out:
# array([[1522,  616],
#        [  65,  296]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(logreg_gs_with_cw, X_train, y_train, normalize='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# #### Test set check

# %%
logreg_gs_with_cw.best_estimator_.score(X_test, y_test)
# Out:
# 0.709832134292566

# %%
print(classification_report(y_test, logreg_gs_with_cw.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.69      0.80       712
#            1       0.31      0.80      0.45       122
#
#     accuracy                           0.71       834
#    macro avg       0.63      0.75      0.63       834
# weighted avg       0.86      0.71      0.75       834

# %%
cm_8 = confusion_matrix(y_test, logreg_gs_with_cw.predict(X_test))
cm_8
# Out:
# array([[494, 218],
#        [ 24,  98]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(logreg_gs_with_cw, X_test, y_test, normalize='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# ## <u>Random Forest

# %% [markdown]
# ### Random Forest Model 1

# %%
baseline_rf_pipe = Pipeline(steps=[
    ('transformer', transformer),
    ('rf', RandomForestClassifier(random_state=5))])

# %%
baseline_rf_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('ss',
#                                                                    StandardScaler())]),
#                                                   Index(['account length', 'international plan', 'voice mail plan',
#        'number vmail messages', 'total day minutes', 'total day calls',
#        'total day charge', 'total eve minutes', 'total eve calls',
#        'total eve charge', 'total night minutes', 'total night calls',
#        'total night charge', 'total intl minutes', 'total intl calls',
#        'total intl charge', 'customer service calls'],
#       dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('ohe',
# ...

# %%
y_pred = baseline_rf_pipe.predict(X_train)

# %% [markdown]
# ### Random Forest Model 1 Evaluation

# %% [markdown]
# #### Train set check

# %%
scores = cross_val_score(baseline_rf_pipe, X_train, y_train, cv=5 )
scores.mean()
# Out:
# 0.935178356713427

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2138
#            1       1.00      1.00      1.00       361
#
#     accuracy                           1.00      2499
#    macro avg       1.00      1.00      1.00      2499
# weighted avg       1.00      1.00      1.00      2499

# %%
cm_rf_1 = confusion_matrix(y_train, y_pred)
cm_rf_1
# Out:
# array([[2138,    0],
#        [   1,  360]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(baseline_rf_pipe, X_train, y_train, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# #### Test set check

# %%
print(classification_report(y_test, baseline_rf_pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96       712
#            1       0.90      0.61      0.73       122
#
#     accuracy                           0.93       834
#    macro avg       0.92      0.80      0.85       834
# weighted avg       0.93      0.93      0.93       834

# %%
cm_rf_2 = confusion_matrix(y_test, baseline_rf_pipe.predict(X_test))
cm_rf_2
# Out:
# array([[704,   8],
#        [ 47,  75]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(baseline_rf_pipe, X_test, y_test, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# ### Random Forest Model 2 (with class weights)

# %%
baseline_rf_pipe_with_cw = Pipeline(steps=[
    ('transformer', transformer),
    ('rf', RandomForestClassifier(random_state=6, class_weight= 'balanced'))])

# %%
baseline_rf_pipe_with_cw.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('ss',
#                                                                    StandardScaler())]),
#                                                   Index(['account length', 'international plan', 'voice mail plan',
#        'number vmail messages', 'total day minutes', 'total day calls',
#        'total day charge', 'total eve minutes', 'total eve calls',
#        'total eve charge', 'total night minutes', 'total night calls',
#        'total night charge', 'total intl minutes', 'total intl calls',
#        'total intl charge', 'customer service calls'],
#       dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('ohe',
# ...

# %%
y_pred = baseline_rf_pipe_with_cw.predict(X_train)

# %% [markdown]
# ### Random Forest Model 2 (with class weights) Evaluation

# %% [markdown]
# #### Train set check

# %%
scores = cross_val_score(baseline_rf_pipe_with_cw, X_train, y_train, cv=5 )
scores.mean()
# Out:
# 0.9159711422845692

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2138
#            1       1.00      1.00      1.00       361
#
#     accuracy                           1.00      2499
#    macro avg       1.00      1.00      1.00      2499
# weighted avg       1.00      1.00      1.00      2499

# %%
cm_rf_3 = confusion_matrix(y_train, y_pred)
cm_rf_3
# Out:
# array([[2138,    0],
#        [   0,  361]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(baseline_rf_pipe_with_cw, X_train, y_train, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# #### Test set check

# %%
print(classification_report(y_test, baseline_rf_pipe_with_cw.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95       712
#            1       0.92      0.49      0.64       122
#
#     accuracy                           0.92       834
#    macro avg       0.92      0.74      0.80       834
# weighted avg       0.92      0.92      0.91       834

# %%
cm_rf_4 = confusion_matrix(y_test, baseline_rf_pipe_with_cw.predict(X_test))
cm_rf_4
# Out:
# array([[707,   5],
#        [ 62,  60]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(baseline_rf_pipe_with_cw, X_test, y_test, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# ### Random Forest Model 3 (with GridSeach and no class weights)

# %%
rf_pipe_gs = Pipeline(steps=[
    ('transformer', transformer),
    ('rf', RandomForestClassifier(random_state= 7))])

# %%
rf_grid = {'rf__criterion': ['gini', 'entropy'],
              'rf__max_depth': [3, 5, 10, 30, 50 ],
              'rf__min_samples_split':[2, 5, 10, 30]
              }

# %%
rf_gs_no_cw =GridSearchCV(estimator=rf_pipe_gs, param_grid = rf_grid, cv = 5)

# %%
rf_gs_no_cw.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('transformer',
#                                         ColumnTransformer(transformers=[('numerical',
#                                                                          Pipeline(steps=[('ss',
#                                                                                           StandardScaler())]),
#                                                                          Index(['account length', 'international plan', 'voice mail plan',
#        'number vmail messages', 'total day minutes', 'total day calls',
#        'total day charge', 'total eve minutes', 'total eve calls',
#        'total eve charge', 'total night minutes', '...
#        'total intl charge', 'customer service calls'],
#       dtype='object')),
#                                                                         ('categorical',
#                                                                          Pipeline(steps=[('ohe',
# ...

# %% [markdown]
# ### Random Forest Model 3 (with Gridsearch and no class weights) Evaluation

# %% [markdown]
# #### Train set check

# %%
rf_gs_no_cw.best_params_
# Out:
# {'rf__criterion': 'gini', 'rf__max_depth': 50, 'rf__min_samples_split': 10}

# %%
rf_gs_no_cw.best_score_
# Out:
# 0.9335759519038076

# %%
rf_gs_no_cw.best_estimator_.score(X_train, y_train)
# Out:
# 0.9811924769907964

# %%
rf_gs_no_cw.best_estimator_.score(X_train, y_train)
# Out:
# 0.9811924769907964

# %%
cm_rf_5 = confusion_matrix(y_train, rf_gs_no_cw.predict(X_train))
cm_rf_5
# Out:
# array([[2138,    0],
#        [  47,  314]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(rf_gs_no_cw, X_train, y_train, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# #### Test set check

# %%
print(classification_report(y_test, rf_gs_no_cw.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96       712
#            1       0.92      0.58      0.71       122
#
#     accuracy                           0.93       834
#    macro avg       0.93      0.79      0.84       834
# weighted avg       0.93      0.93      0.92       834

# %%
cm_rf_6 = confusion_matrix(y_test, rf_gs_no_cw.predict(X_test))
cm_rf_6
# Out:
# array([[706,   6],
#        [ 51,  71]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(rf_gs_no_cw, X_test, y_test, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# ### Random Forest Model 4 (with Gridsearch and class weights)

# %%
rf_pipe_gs_with_cw = Pipeline(steps=[
    ('transformer', transformer),
    ('rf', RandomForestClassifier(random_state= 8, class_weight='balanced'))])

# %%
rf_gs_with_cw =GridSearchCV(estimator=rf_pipe_gs_with_cw, param_grid = rf_grid, scoring = 'recall', cv = 5)

# %%
rf_gs_with_cw.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('transformer',
#                                         ColumnTransformer(transformers=[('numerical',
#                                                                          Pipeline(steps=[('ss',
#                                                                                           StandardScaler())]),
#                                                                          Index(['account length', 'international plan', 'voice mail plan',
#        'number vmail messages', 'total day minutes', 'total day calls',
#        'total day charge', 'total eve minutes', 'total eve calls',
#        'total eve charge', 'total night minutes', '...
#       dtype='object')),
#                                                                         ('categorical',
#                                                                          Pipeline(steps=[('ohe',
# ...

# %% [markdown]
# ### Random Forest Model 4 (with Gridsearch and class weights) Evaluation

# %% [markdown]
# #### Train set check

# %%
rf_gs_with_cw.best_params_
# Out:
# {'rf__criterion': 'entropy', 'rf__max_depth': 30, 'rf__min_samples_split': 30}

# %%
rf_gs_with_cw.best_score_
# Out:
# 0.7590943683409437

# %%
rf_gs_with_cw.best_estimator_.score(X_train, y_train)
# Out:
# 0.9659863945578231

# %%
rf_gs_with_cw.best_estimator_
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('ss',
#                                                                    StandardScaler())]),
#                                                   Index(['account length', 'international plan', 'voice mail plan',
#        'number vmail messages', 'total day minutes', 'total day calls',
#        'total day charge', 'total eve minutes', 'total eve calls',
#        'total eve charge', 'total night minutes', 'total night calls',
#        'total night..., 'total intl minutes', 'total intl calls',
#        'total intl charge', 'customer service calls'],
#       dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
# ...

# %%
rf_gs_with_cw.best_estimator_.score(X_train, y_train)
# Out:
# 0.9659863945578231

# %%
cm_rf_7 = confusion_matrix(y_train, rf_gs_with_cw.predict(X_train))
cm_rf_7
# Out:
# array([[2087,   51],
#        [  34,  327]], dtype=int64)

# %%
print(classification_report(y_train, rf_gs_with_cw.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      2138
#            1       0.87      0.91      0.88       361
#
#     accuracy                           0.97      2499
#    macro avg       0.92      0.94      0.93      2499
# weighted avg       0.97      0.97      0.97      2499

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(rf_gs_with_cw, X_train, y_train, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# #### Test set check

# %%
print(classification_report(y_test, rf_gs_with_cw.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       712
#            1       0.77      0.80      0.78       122
#
#     accuracy                           0.94       834
#    macro avg       0.87      0.88      0.87       834
# weighted avg       0.94      0.94      0.94       834

# %%
cm_rf_8 = confusion_matrix(y_test, rf_gs_with_cw.predict(X_test))
cm_rf_8
# Out:
# array([[683,  29],
#        [ 25,  97]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(rf_gs_with_cw, X_test, y_test, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# ## <u>KNN

# %% [markdown]
# ### KNN Model 1

# %%
baseline_knn_pipe = Pipeline(steps=[
    ('transformer', transformer),
    ('knn', KNeighborsClassifier())])

# %%
baseline_knn_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('ss',
#                                                                    StandardScaler())]),
#                                                   Index(['account length', 'international plan', 'voice mail plan',
#        'number vmail messages', 'total day minutes', 'total day calls',
#        'total day charge', 'total eve minutes', 'total eve calls',
#        'total eve charge', 'total night minutes', 'total night calls',
#        'total night charge', 'total intl minutes', 'total intl calls',
#        'total intl charge', 'customer service calls'],
#       dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('ohe',
# ...

# %%
y_pred = baseline_knn_pipe.predict(X_train)

# %% [markdown]
# ### KNN Model 1 Evaluation

# %% [markdown]
# #### Train set check

# %%
scores = cross_val_score(baseline_knn_pipe, X_train, y_train, cv=5 )
scores.mean()
# Out:
# 0.8863575150300601

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      2138
#            1       0.88      0.50      0.63       361
#
#     accuracy                           0.92      2499
#    macro avg       0.90      0.74      0.79      2499
# weighted avg       0.92      0.92      0.91      2499

# %%
cm_knn_1 = confusion_matrix(y_train, y_pred)
cm_knn_1
# Out:
# array([[2114,   24],
#        [ 182,  179]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(baseline_knn_pipe, X_train, y_train, normalize='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# #### Test set check

# %%
print(classification_report(y_test, baseline_knn_pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94       712
#            1       0.83      0.35      0.49       122
#
#     accuracy                           0.89       834
#    macro avg       0.86      0.67      0.72       834
# weighted avg       0.89      0.89      0.88       834

# %%
cm_knn_2 = confusion_matrix(y_test, baseline_knn_pipe.predict(X_test))
cm_knn_2
# Out:
# array([[703,   9],
#        [ 79,  43]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(baseline_knn_pipe, X_test, y_test, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# ### KNN Model 2 (with SMOTENC)

# %%
from imblearn.over_sampling import SMOTENC
from imblearn.pipeline import Pipeline as ImPipeline

# %%
baseline_knn_pipe_with_sm = ImPipeline(steps=[('transformer', transformer),
                             ('sm', SMOTENC(categorical_features= list(range(17, 67+1)), random_state=1)),
                            ('knn', KNeighborsClassifier())])

# %%
baseline_knn_pipe_with_sm.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('ss',
#                                                                    StandardScaler())]),
#                                                   Index(['account length', 'international plan', 'voice mail plan',
#        'number vmail messages', 'total day minutes', 'total day calls',
#        'total day charge', 'total eve minutes', 'total eve calls',
#        'total eve charge', 'total night minutes', 'total night calls',
#        'total night...
#        'total intl charge', 'customer service calls'],
#       dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
# ...

# %%
y_pred_sm = baseline_knn_pipe_with_sm.predict(X_train)

# %% [markdown]
# ### KNN Model 2 (with SMOTENC) Evaluation

# %% [markdown]
# #### Train set check

# %%
scores = cross_val_score(baseline_knn_pipe_with_sm, X_train, y_train, cv=5 )
scores.mean()
# Out:
# 0.7359022044088176

# %%
print(classification_report(y_train, y_pred_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89      2138
#            1       0.45      1.00      0.62       361
#
#     accuracy                           0.83      2499
#    macro avg       0.73      0.90      0.76      2499
# weighted avg       0.92      0.83      0.85      2499

# %%
cm_knn_3 = confusion_matrix(y_train, baseline_knn_pipe_with_sm.predict(X_train))
cm_knn_3
# Out:
# array([[1705,  433],
#        [   1,  360]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(baseline_knn_pipe_with_sm, X_train, y_train, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# #### Test set check

# %%
print(classification_report(y_test, baseline_knn_pipe_with_sm.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.72      0.82       712
#            1       0.32      0.77      0.46       122
#
#     accuracy                           0.73       834
#    macro avg       0.64      0.75      0.64       834
# weighted avg       0.86      0.73      0.77       834

# %%
cm_knn_4 = confusion_matrix(y_test, baseline_knn_pipe_with_sm.predict(X_test))
cm_knn_4
# Out:
# array([[515, 197],
#        [ 28,  94]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(baseline_knn_pipe_with_sm, X_test, y_test, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# ### KNN Model 3 (with GridSearch and no SMOTENC)

# %%
knn_pipe_gs_no_sm = Pipeline(steps=[
    ('transformer', transformer),
    ('knn', KNeighborsClassifier())])

# %%
knn_grid = {'knn__n_neighbors': [5, 10, 30, 50, 100],
            'knn__p':[1, 2, 3],
            'knn__metric':['minkowski', 'euclidean', 'manhattan']
              }

# %%
knn_gs_no_sm =GridSearchCV(estimator=knn_pipe_gs_no_sm, param_grid = knn_grid, cv = 5)

# %%
knn_gs_no_sm.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('transformer',
#                                         ColumnTransformer(transformers=[('numerical',
#                                                                          Pipeline(steps=[('ss',
#                                                                                           StandardScaler())]),
#                                                                          Index(['account length', 'international plan', 'voice mail plan',
#        'number vmail messages', 'total day minutes', 'total day calls',
#        'total day charge', 'total eve minutes', 'total eve calls',
#        'total eve charge', 'total night minutes', '...
#        'total night charge', 'total intl minutes', 'total intl calls',
#        'total intl charge', 'customer service calls'],
#       dtype='object')),
#                                                                         ('categorical',
# ...

# %% [markdown]
# ### KNN Model 3 (with GridSearch and no SMOTENC) Evaluation

# %% [markdown]
# #### Train set check

# %%
knn_gs_no_sm.best_params_
# Out:
# {'knn__metric': 'minkowski', 'knn__n_neighbors': 5, 'knn__p': 3}

# %%
knn_gs_no_sm.best_score_
# Out:
# 0.8867575150300601

# %%
knn_gs_no_sm.best_estimator_.score(X_train, y_train)
# Out:
# 0.9191676670668267

# %%
knn_gs_no_sm.best_estimator_.score(X_train, y_train)
# Out:
# 0.9191676670668267

# %%
cm_knn_5 = confusion_matrix(y_train, knn_gs_no_sm.predict(X_train))
cm_knn_5
# Out:
# array([[2119,   19],
#        [ 183,  178]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(knn_gs_no_sm, X_train, y_train, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# #### Test set check

# %%
print(classification_report(y_test, knn_gs_no_sm.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94       712
#            1       0.81      0.34      0.48       122
#
#     accuracy                           0.89       834
#    macro avg       0.85      0.67      0.71       834
# weighted avg       0.88      0.89      0.87       834

# %%
cm_knn_6 = confusion_matrix(y_test, knn_gs_no_sm.predict(X_test))
cm_knn_6
# Out:
# array([[702,  10],
#        [ 80,  42]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(knn_gs_no_sm, X_test, y_test, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# ### KNN Model 4 (with GridSearch and SMOTENC)

# %%
knn_pipe_gs_with_sm = ImPipeline(steps=[('transformer', transformer),
                             ('sm', SMOTENC(categorical_features= list(range(17, 67+1)), random_state=2)),
                            ('knn', KNeighborsClassifier())])

# %%
knn_gs_with_sm =GridSearchCV(estimator=knn_pipe_gs_with_sm, param_grid = knn_grid, scoring = 'recall', cv = 5)

# %%
knn_gs_with_sm.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('transformer',
#                                         ColumnTransformer(transformers=[('numerical',
#                                                                          Pipeline(steps=[('ss',
#                                                                                           StandardScaler())]),
#                                                                          Index(['account length', 'international plan', 'voice mail plan',
#        'number vmail messages', 'total day minutes', 'total day calls',
#        'total day charge', 'total eve minutes', 'total eve calls',
#        'total eve charge', 'total night minutes', '...
#                                                                          Index(['state'], dtype='object'))])),
#                                        ('sm',
#                                         SMOTENC(categorical_features=[17, 18,
# ...

# %% [markdown]
# ### KNN Model 4 (with GridSearch and SMOTENC) Evaluation

# %% [markdown]
# #### Train set check

# %%
knn_gs_with_sm.best_params_
# Out:
# {'knn__metric': 'minkowski', 'knn__n_neighbors': 100, 'knn__p': 1}

# %%
knn_gs_with_sm.best_score_
# Out:
# 0.8948630136986301

# %%
knn_gs_with_sm.best_estimator_.score(X_train, y_train)
# Out:
# 0.7318927571028412

# %%
cm_knn_7 = confusion_matrix(y_train, rf_gs_with_cw.predict(X_train))
cm_knn_7
# Out:
# array([[2087,   51],
#        [  34,  327]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(knn_gs_with_sm, X_train, y_train, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# #### Test set check

# %%
print(classification_report(y_test, knn_gs_with_sm.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.68      0.80       712
#            1       0.32      0.86      0.46       122
#
#     accuracy                           0.71       834
#    macro avg       0.64      0.77      0.63       834
# weighted avg       0.87      0.71      0.75       834

# %%
cm_knn_8 = confusion_matrix(y_test, knn_gs_with_sm.predict(X_test))
cm_knn_8
# Out:
# array([[484, 228],
#        [ 17, 105]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(knn_gs_with_sm, X_test, y_test, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# ## <u>XGBoost

# %% [markdown]
# ### XGBoost Model 1

# %%
baseline_xgb_pipe = Pipeline(steps=[
    ('transformer', transformer),
    ('xgboost', XGBClassifier(random_state=13))])

baseline_xgb_pipe.fit(X_train, y_train)
y_pred = baseline_xgb_pipe.predict(X_train)
# Out:
# [11:22:52] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\Jonathan\anaconda3\envs\learn-env\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %% [markdown]
# ### XGBoost Model 1 Evaluation

# %% [markdown]
# #### Train set check

# %%
scores = cross_val_score(baseline_xgb_pipe, X_train, y_train, cv=5 )
scores.mean()
# Out:
# C:\Users\Jonathan\anaconda3\envs\learn-env\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:22:52] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:22:52] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2138
#            1       1.00      1.00      1.00       361
#
#     accuracy                           1.00      2499
#    macro avg       1.00      1.00      1.00      2499
# weighted avg       1.00      1.00      1.00      2499

# %%
cm_xgb_1 = confusion_matrix(y_train, y_pred)
cm_xgb_1
# Out:
# array([[2138,    0],
#        [   0,  361]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(16, 10))
plot_confusion_matrix(baseline_xgb_pipe, X_train, y_train, normalize='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# #### Test set check

# %%
scores = cross_val_score(baseline_xgb_pipe, X_test, y_test, cv=5 )
scores.mean()
# Out:
# C:\Users\Jonathan\anaconda3\envs\learn-env\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\Jonathan\anaconda3\envs\learn-env\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# ...

# %%
print(classification_report(y_test, baseline_xgb_pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       712
#            1       0.85      0.76      0.81       122
#
#     accuracy                           0.95       834
#    macro avg       0.91      0.87      0.89       834
# weighted avg       0.94      0.95      0.94       834

# %%
cm_xgb_1 = confusion_matrix(y_test,  baseline_xgb_pipe.predict(X_test) )
cm_xgb_1
# Out:
# array([[696,  16],
#        [ 29,  93]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(16, 10))
plot_confusion_matrix(baseline_xgb_pipe, X_test, y_test, normalize='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# ### XGBoost Model 2 (with GridSearch)

# %%
xgb_pipe_with_gs = Pipeline(steps=[
    ('transformer', transformer),
    ('xgb', XGBClassifier(random_state=14))])

# %%
xgb_grid = {
    'xgb__learning_rate': [0.1, 0.3, 0.5, ],
    'xgb__max_depth': [6, 10, 20],
    'xgb__min_child_weight': [1, 2],
    'xgb__subsample': [0.3, 0.5, 0.7],
    'xgb__n_estimators': [100]
}

# %%
xgb_gs = GridSearchCV(estimator = xgb_pipe_with_gs, param_grid = xgb_grid, scoring = 'recall', cv = 5)

# %%
xgb_gs.fit(X_train, y_train)
# Out:
# C:\Users\Jonathan\anaconda3\envs\learn-env\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\Jonathan\anaconda3\envs\learn-env\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# ...

# %% [markdown]
# ### XGBoost Model 2 (with GridSearch) Evaluation

# %% [markdown]
# #### Train set check

# %%
xgb_gs.best_params_
# Out:
# {'xgb__learning_rate': 0.1,
#  'xgb__max_depth': 10,
#  'xgb__min_child_weight': 1,
#  'xgb__n_estimators': 100,
#  'xgb__subsample': 0.7}

# %%
xgb_gs.best_score_
# Out:
# 0.7620243531202435

# %%
xgb_gs.best_estimator_.score(X_train, y_train)
# Out:
# 0.9987995198079231

# %%
cm_xgb_3 = confusion_matrix(y_train, xgb_gs.predict(X_train))
cm_xgb_3
# Out:
# array([[2138,    0],
#        [   3,  358]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(xgb_gs, X_train, y_train, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);

# %% [markdown]
# #### Test set check

# %%
print(classification_report(y_test, xgb_gs.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       712
#            1       0.91      0.76      0.83       122
#
#     accuracy                           0.95       834
#    macro avg       0.94      0.87      0.90       834
# weighted avg       0.95      0.95      0.95       834

# %%
cm_xgb_4 = confusion_matrix(y_test, xgb_gs.predict(X_test))
cm_xgb_4
# Out:
# array([[703,   9],
#        [ 29,  93]], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(xgb_gs, X_test, y_test, normalize ='true', cmap= 'Greens', ax=ax)
plt.grid(False);
